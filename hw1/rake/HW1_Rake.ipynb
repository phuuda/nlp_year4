# %%
from __future__ import absolute_import
from __future__ import print_function
import six
__author__ = 'a_medelyan'

import rake
import operator
import io

# EXAMPLE ONE - SIMPLE
#stoppath = "SmartStoplist.txt"
stoppath = "RussianStoplist.txt"

# 1. initialize RAKE by providing a path to a stopwords file
rake_object = rake.Rake(stoppath, 5, 3, 4)

# 2. run on RAKE on a given text
#sample_file = io.open("data/docs/fao_test/w2167e.txt", 'r',encoding="iso-8859-1")
#sample_file = io.open("discourse.txt", 'r',encoding="utf-8")
#sample_file = io.open("rake_eng_text.txt", 'r',encoding="utf-8")
sample_file = io.open("rake_rus_text.txt", 'r',encoding="utf-8")
text = sample_file.read()

keywords = rake_object.run(text)

# 3. print results
print("Keywords:", keywords)

print("----------")
# EXAMPLE TWO - BEHIND THE SCENES (from https://github.com/aneesha/RAKE/rake.py)

# 1. initialize RAKE by providing a path to a stopwords file
rake_object = rake.Rake(stoppath)

#text = "Compatibility of systems of linear constraints over the set of natural numbers. Criteria of compatibility " \
#       "of a system of linear Diophantine equations, strict inequations, and nonstrict inequations are considered. " \
#       "Upper bounds for components of a minimal set of solutions and algorithms of construction of minimal generating"\
#       " sets of solutions for all types of systems are given. These criteria and the corresponding algorithms " \
#       "for constructing a minimal supporting set of solutions can be used in solving all the considered types of " \
#       "systems and systems of mixed types."

# 1. Split text into sentences
sentenceList = rake.split_sentences(text)

for sentence in sentenceList:
    print("Sentence:", sentence)

# generate candidate keywords
stopwords = rake.load_stop_words(stoppath)
stopwordpattern = rake.build_stop_word_regex(stoppath)
phraseList = rake.generate_candidate_keywords(sentenceList, stopwordpattern, stopwords)
print("Phrases:", phraseList)

# calculate individual word scores
wordscores = rake.calculate_word_scores(phraseList)

# generate candidate keyword scores
keywordcandidates = rake.generate_candidate_keyword_scores(phraseList, wordscores)
#for candidate in keywordcandidates.keys():
#    print("Candidate: ", candidate, ", score: ", keywordcandidates.get(candidate))

# sort candidates by score to determine top-scoring keywords
sortedKeywords = sorted(six.iteritems(keywordcandidates), key=operator.itemgetter(1), reverse=True)
totalKeywords = len(sortedKeywords)

# for example, you could just take the top third as the final keywords
for keyword in sortedKeywords[0:int(totalKeywords / 3)]:
    print("Keyword: ", keyword[0], ", score: ", keyword[1])

for phrase in rake_object.run(text): 
    print(phrase)
# Out:
# Keywords: []
# ----------
# Sentence: Ливневый дождь — дождь ливневого характера
# Sentence:  отличающийся высокой интенсивностью
# Sentence: порой до 100 мм/ч
# Sentence:
# Sentence:  Относится к ливневым осадкам
# Sentence:  Ливневые дожди возникают в неустойчивых воздушных массах на холодных атмосферных фронтах или в результате конвекции
# Sentence:  Выпадают из кучево
# Sentence: дождевых облаков
# Sentence:  Облачность при этом может быть как значительной
# Sentence: 7—9 баллов
# Sentence:
# Sentence:  так и небольшой
# Sentence: 4—6
# Sentence:
# Sentence:  иногда даже 2—3 балла
# Sentence:  В жаркую погоду они появляются также из мощно
# Sentence: кучевых облаков
# Sentence:  а слабый ливневый дождь может выпадать даже из средних кучевых облаков
# Sentence:  Как правило
# Sentence:  ливневый дождь охватывает относительно небольшую территорию
# Sentence:  Длительность выпадения ливневого дождя обычно небольшая
# Sentence:  в среднем от нескольких минут до 1—2 часов
# Sentence:  но иногда такие осадки могут затягиваться и на несколько суток
# Sentence: в тропических широтах
# Sentence:
# Sentence:  Данное атмосферное явление часто сопровождается грозой и шквалами ветра
# Sentence:  Ливневые дожди могут приводить к катастрофическим последствиям в результате затопления территорий
# Sentence:  При интенсивности свыше 1
# Sentence: 5—2 мм в минуту
# Sentence: слой воды в 1 мм соответствует 1 литру воды на каждый квадратный метр
# Sentence:  человеку становится трудно дышать
# Sentence:  Самый сильный ливень на Земле был зарегистрирован 14 июля 1876 года в индийском городе Черапунджи в штате Мегхалая
# Sentence:  за сутки выпало более 1000 мм осадков
# Sentence:  С сильными ливнями
# Sentence:  вероятно
# Sentence:  связаны легенды о Всемирном потопе
# Sentence:  В Ветхом завете говорится
# Sentence:  что «был дождь на земле сорок дней и сорок ночей
# Sentence:  И было наводнение сорок дней на земле
# Sentence:  и умножилась вода и подняла ковчег
# Sentence:  и он возвысился на землёй»
# Sentence:  Согласно библейским преданиям
# Sentence:  воды выпало настолько много
# Sentence:  что Ноев ковчег смог причалить лишь к вершине горы Арарат
# Sentence:  так как вся остальная территория была затоплена
# Sentence:  По расчётам метеорологов
# Sentence:  чтобы за 40 дней образовался слой воды в 5165 метров
# Sentence: высота горы Арарат
# Sentence:
# Sentence:  необходимо
# Sentence:  чтобы интенсивность ливня составляла около 100 мм в минуту
# Sentence:
# Phrases: ['ливневый', 'дождь — дождь', 'ливневого', 'характера', 'отличающийся', 'высокой', 'интенсивностью', 'порой', 'до', 'мм', 'относится', 'ливневым', 'осадкам', 'ливневые', 'дожди', 'возникают', 'неустойчивых', 'воздушных', 'массах', 'на', 'холодных', 'атмосферных', 'фронтах', 'или', 'результате', 'конвекции', 'выпадают', 'из', 'кучево', 'дождевых', 'облаков', 'облачность', 'при', 'этом', 'может', 'быть', 'как', 'значительной', 'баллов', 'так', 'небольшой', 'иногда', 'даже', 'балла', 'жаркую', 'погоду', 'они', 'появляются', 'также', 'из', 'мощно', 'кучевых', 'облаков', 'слабый', 'ливневый', 'дождь', 'может', 'выпадать', 'даже', 'из', 'средних', 'кучевых', 'облаков', 'как', 'правило', 'ливневый', 'дождь', 'охватывает', 'относительно', 'небольшую', 'территорию', 'длительность', 'выпадения', 'ливневого', 'дождя', 'обычно', 'небольшая', 'среднем', 'от', 'нескольких', 'минут', 'до', 'часов', 'но', 'иногда', 'такие', 'осадки', 'могут', 'затягиваться', 'на', 'несколько', 'суток', 'тропических', 'широтах', 'данное', 'атмосферное', 'явление', 'часто', 'сопровождается', 'грозой', 'шквалами', 'ветра', 'ливневые', 'дожди', 'могут', 'приводить', 'катастрофическим', 'последствиям', 'результате', 'затопления', 'территорий', 'при', 'интенсивности', 'свыше', 'мм', 'минуту', 'слой', 'воды', 'мм', 'соответствует', 'литру', 'воды', 'на', 'каждый', 'квадратный', 'метр', 'человеку', 'становится', 'трудно', 'дышать', 'самый', 'сильный', 'ливень', 'на', 'земле', 'был', 'зарегистрирован', 'июля', 'года', 'индийском', 'городе', 'черапунджи', 'штате', 'мегхалая', 'за', 'сутки', 'выпало', 'более', 'мм', 'осадков', 'сильными', 'ливнями', 'вероятно', 'связаны', 'легенды', 'всемирном', 'потопе', 'ветхом', 'завете', 'говорится', 'что «был', 'дождь', 'на', 'земле', 'сорок', 'дней', 'сорок', 'ночей', 'было', 'наводнение', 'сорок', 'дней', 'на', 'земле', 'умножилась', 'вода', 'подняла', 'ковчег', 'он', 'возвысился', 'на', 'землёй»', 'согласно', 'библейским', 'преданиям', 'воды', 'выпало', 'настолько', 'много', 'что', 'ноев', 'ковчег', 'смог', 'причалить', 'лишь', 'вершине', 'горы', 'арарат', 'так', 'как', 'вся', 'остальная', 'территория', 'была', 'затоплена', 'по', 'расчётам', 'метеорологов', 'чтобы', 'за', 'дней', 'образовался', 'слой', 'воды', 'метров', 'высота', 'горы', 'арарат', 'необходимо', 'чтобы', 'интенсивность', 'ливня', 'составляла', 'около', 'мм', 'минуту']
# Keyword:  ливневый , score:  0
# Keyword:  дождь — дождь , score:  0
# Keyword:  ливневого , score:  0
# Keyword:  характера , score:  0
# Keyword:  отличающийся , score:  0
# Keyword:  высокой , score:  0
# Keyword:  интенсивностью , score:  0
# Keyword:  порой , score:  0
# Keyword:  до , score:  0
# Keyword:  мм , score:  0
# Keyword:  относится , score:  0
# Keyword:  ливневым , score:  0
# Keyword:  осадкам , score:  0
# Keyword:  ливневые , score:  0
# Keyword:  дожди , score:  0
# Keyword:  возникают , score:  0
# Keyword:  неустойчивых , score:  0
# Keyword:  воздушных , score:  0
# Keyword:  массах , score:  0
# Keyword:  на , score:  0
# Keyword:  холодных , score:  0
# Keyword:  атмосферных , score:  0
# Keyword:  фронтах , score:  0
# Keyword:  или , score:  0
# Keyword:  результате , score:  0
# Keyword:  конвекции , score:  0
# Keyword:  выпадают , score:  0
# Keyword:  из , score:  0
# Keyword:  кучево , score:  0
# Keyword:  дождевых , score:  0
# Keyword:  облаков , score:  0
# Keyword:  облачность , score:  0
# Keyword:  при , score:  0
# Keyword:  этом , score:  0
# Keyword:  может , score:  0
# Keyword:  быть , score:  0
# Keyword:  как , score:  0
# Keyword:  значительной , score:  0
# Keyword:  баллов , score:  0
# Keyword:  так , score:  0
# Keyword:  небольшой , score:  0
# Keyword:  иногда , score:  0
# Keyword:  даже , score:  0
# Keyword:  балла , score:  0
# Keyword:  жаркую , score:  0
# Keyword:  погоду , score:  0
# Keyword:  они , score:  0
# Keyword:  появляются , score:  0
# Keyword:  также , score:  0
# Keyword:  мощно , score:  0
# Keyword:  кучевых , score:  0
# Keyword:  слабый , score:  0
# Keyword:  дождь , score:  0
# Keyword:  выпадать , score:  0
# Keyword:  средних , score:  0
# Keyword:  правило , score:  0
# Keyword:  охватывает , score:  0
# Keyword:  относительно , score:  0
# Keyword:  небольшую , score:  0
# ('отличающийся высокой интенсивностью', 0)
# ('порой до 100 мм/ч', 0)
# ('относится к ливневым осадкам', 0)
# ('выпадают из кучево', 0)
# ('дождевых облаков', 0)
# ('облачность при', 0)
# ('значительной', 0)
# ('7—9 баллов', 0)
# ('и небольшой', 0)
# ('иногда даже 2—3 балла', 0)
# ('в жаркую погоду', 0)
# ('появляются также из мощно', 0)
# ('кучевых облаков', 0)
# ('а слабый ливневый дождь', 0)
# ('правило', 0)
# ('но иногда', 0)
# ('осадки', 0)
# ('затягиваться и на несколько суток', 0)
# ('в тропических широтах', 0)
# ('ливневые дожди', 0)
# ('при интенсивности свыше 1', 0)
# ('5—2 мм в минуту', 0)
# ('человеку становится трудно дышать', 0)
# ('самый сильный ливень на земле', 0)
# ('с сильными ливнями', 0)
# ('вероятно', 0)
# ('связаны легенды о всемирном потопе', 0)
# ('в ветхом завете говорится', 0)
# ('и', 0)
# ('наводнение сорок дней на земле', 0)
# ('возвысился на землёй»', 0)
# ('согласно библейским преданиям', 0)
# ('воды выпало настолько много', 0)
# ('остальная территория', 0)
# ('затоплена', 0)
# ('по расчётам метеорологов', 0)
# ('высота горы арарат', 0)
# ('необходимо', 0)
