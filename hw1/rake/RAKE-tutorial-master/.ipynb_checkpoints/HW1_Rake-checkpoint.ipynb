# %%
from __future__ import absolute_import
from __future__ import print_function
import six
__author__ = 'a_medelyan'

import rake
import operator
import io

# EXAMPLE ONE - SIMPLE
#stoppath = "SmartStoplist.txt"
stoppath = "RussianStoplist.txt"

# 1. initialize RAKE by providing a path to a stopwords file
rake_object = rake.Rake(stoppath, 5, 3, 4)

# 2. run on RAKE on a given text
#sample_file = io.open("data/docs/fao_test/w2167e.txt", 'r',encoding="iso-8859-1")
#sample_file = io.open("discourse.txt", 'r',encoding="utf-8")
#sample_file = io.open("rake_eng_text.txt", 'r',encoding="utf-8")
sample_file = io.open("rake_rus_text.txt", 'r',encoding="utf-8")
text = sample_file.read()

keywords = rake_object.run(text)

# 3. print results
print("Keywords:", keywords)

print("----------")
# EXAMPLE TWO - BEHIND THE SCENES (from https://github.com/aneesha/RAKE/rake.py)

# 1. initialize RAKE by providing a path to a stopwords file
rake_object = rake.Rake(stoppath)

#text = "Compatibility of systems of linear constraints over the set of natural numbers. Criteria of compatibility " \
#       "of a system of linear Diophantine equations, strict inequations, and nonstrict inequations are considered. " \
#       "Upper bounds for components of a minimal set of solutions and algorithms of construction of minimal generating"\
#       " sets of solutions for all types of systems are given. These criteria and the corresponding algorithms " \
#       "for constructing a minimal supporting set of solutions can be used in solving all the considered types of " \
#       "systems and systems of mixed types."

# 1. Split text into sentences
sentenceList = rake.split_sentences(text)

for sentence in sentenceList:
    print("Sentence:", sentence)

# generate candidate keywords
stopwords = rake.load_stop_words(stoppath)
stopwordpattern = rake.build_stop_word_regex(stoppath)
phraseList = rake.generate_candidate_keywords(sentenceList, stopwordpattern, stopwords)
print("Phrases:", phraseList)

# calculate individual word scores
wordscores = rake.calculate_word_scores(phraseList)

# generate candidate keyword scores
keywordcandidates = rake.generate_candidate_keyword_scores(phraseList, wordscores)
#for candidate in keywordcandidates.keys():
#    print("Candidate: ", candidate, ", score: ", keywordcandidates.get(candidate))

# sort candidates by score to determine top-scoring keywords
sortedKeywords = sorted(six.iteritems(keywordcandidates), key=operator.itemgetter(1), reverse=True)
totalKeywords = len(sortedKeywords)

# for example, you could just take the top third as the final keywords
for keyword in sortedKeywords[0:int(totalKeywords / 3)]:
    print("Keyword: ", keyword[0], ", score: ", keyword[1])

for phrase in rake_object.run(text): 
    print(phrase)
# Out:
# Keywords: [('пожалуйста', 0), ('правда', 0), ('после', 0), ('причём', 0), ('к сожалению', 0), ('человек', 0), ('сегодня', 0), ('в общем', 0), ('кроме', 0), ('впрочем', 0), ('например', 0), ('сейчас', 0), ('теперь', 0), ('кстати', 0), ('чтобы', 0), ('можно', 0), ('видимо', 0), ('наверное', 0), ('больше', 0), ('в первую очередь', 0), ('государство', 0), ('образом', 0), ('возможно', 0), ('благодаря', 0), ('выяснилось', 0), ('всегда', 0), ('поэтому', 0), ('считаю', 0), ('стороны', 0), ('но при', 0), ('соответственно', 0), ('судите сами', 0), ('разумеется', 0), ('однако', 0), ('значит', 0), ('сделать', 0), ('компании', 0), ('не менее', 0), ('скорее', 0), ('потому', 0), ('конечно же', 0), ('конечно', 0), ('проблемы', 0), ('не знаю', 0), ('сызраньсельмаша', 0), ('здесь', 0), ('наконец', 0), ('к примеру', 0), ('компания', 0), ('почему', 0), ('жигулёвское пиво', 0), ('стране', 0), ('философ', 0), ('музыка', 0), ('ладно', 0), ('очевидно', 0), ('пожалуй', 0), ('именно', 0), ('видно', 0), ('вероятно', 0), ('известно', 0), ('действительно', 0), ('время', 0), ('вопрос', 0), ('между', 0), ('вообще', 0), ('говорил', 0), ('более', 0), ('дело в', 0), ('говорят', 0), ('естественно', 0), ('в россии', 0), ('много', 0), ('смысл', 0), ('случае', 0), ('хорошо', 0), ('устал', 0), ('людей', 0), ('оказывается', 0), ('нужно', 0), ('человеком', 0), ('осенью', 0), ('обычно', 0), ('правило', 0), ('процессов', 0), ('тогда', 0), ('несмотря на', 0), ('первых', 0), ('в частности', 0), ('следовательно', 0), ('панавто', 0), ('скажем', 0), ('точно', 0), ('ответ', 0), ('другому', 0), ('долларов', 0), ('кажется', 0), ('нибудь', 0), ('знаете', 0), ('жизнь', 0), ('а также', 0), ('означает', 0), ('должны', 0), ('с другой стороны', 0), ('лучше', 0), ('делать', 0), ('главное', 0), ('думаю', 0), ('казалось', 0), ('жизни', 0), ('должен', 0), ('интересно', 0), ('прежде', 0), ('среди', 0), ('интернет', 0), ('далее', 0), ('внутри', 0), ('тираж', 0), ('лучшие показатели', 0), ('перед', 0), ('единая россия', 0), ('яблока', 0), ('единой россии', 0), ('потом', 0), ('зачем', 0), ('слово', 0), ('завтра', 0), ('сказал', 0), ('подумал', 0), ('закричал', 0), ('спросил', 0), ('иногда', 0), ('сказал медвежонок', 0), ('баранкин', 0), ('малинин', 0), ('костя', 0), ('говорит', 0), ('ребята', 0), ('мирмики', 0)]
# ----------
# Sentence: Гостиницы
# Sentence: С ума сойти
# Sentence:
# Sentence: В гостинице
# Sentence:  где «всё для клиента»
# Sentence:
# Sentence: Хорошо ли вы спали
# Sentence:
# Sentence:
# Sentence:  спрашивает хозяин гостиницы
# Sentence:
# Sentence: Пожалуйста
# Sentence:
# Sentence: Пожалуйста
# Sentence:  получите
# Sentence:
# Sentence: Ни в коем случае
# Sentence:  мсьё
# Sentence:
# Sentence:
# Sentence:
# Sentence: Та
# Sentence:  что поменьше
# Sentence:  не пропускает комаров
# Sentence:  а та
# Sentence:  что с большими ячейками
# Sentence:  не пропускает мух
# Sentence:
# Sentence: Нет
# Sentence:
# Sentence: И он всё ещё продолжает петь
# Sentence:
# Sentence: Приезжий остановился в отеле небольшого провинциального города и
# Sentence:  ложась спать
# Sentence:  приказал разбудить себя в 5 часов утра
# Sentence:
# Sentence: У вас худая крыша
# Sentence:
# Sentence: Мне сдаётся
# Sentence:  мадам
# Sentence:  что вам следовало бы получше кормить ваших жильцов
# Sentence:
# Sentence: Как же выглядит комната без удобств
# Sentence:
# Sentence: Играть на музыкальных инструментах
# Sentence:
# Sentence: Анекдот об анекдоте
# Sentence: Победителем оказался солдат
# Sentence:  приславший следующее
# Sentence:  «Я подпилил ножки унитаза
# Sentence:
# Sentence:
# Sentence:
# Sentence: Палитицкий
# Sentence:
# Sentence: Нет
# Sentence:
# Sentence: Расскажи
# Sentence:
# Sentence: Вашему анекдоту как минимум лет пятьдесят
# Sentence:  мадам
# Sentence:
# Sentence: Результат начинался так
# Sentence:  «Лежат в постели три еврея
# Sentence:  Чапаев
# Sentence:  Чебурашка и поручик Ржевский
# Sentence:
# Sentence:
# Sentence: »
# Sentence:
# Sentence: Миллионер пригласил на обед «сливки общества»
# Sentence:
# Sentence: Да
# Sentence:  но вы от очень хорошенькой
# Sentence:
# Sentence: Видите ли
# Sentence:
# Sentence:
# Sentence:  ответил писатель
# Sentence:
# Sentence:
# Sentence:  природа любит равновесие
# Sentence:
# Sentence: Шоу ответил
# Sentence:
# Sentence: Английская королева
# Sentence:  узнав об этом
# Sentence:  при встрече с Шоу спросила
# Sentence:
# Sentence: На что они ответили
# Sentence:
# Sentence: Перенос сроков и перерасход по смете
# Sentence:
# Sentence:  это вечная головная боль
# Sentence: в основном
# Sentence:  правда
# Sentence:  для заказчика
# Sentence:
# Sentence:
# Sentence: Тот
# Sentence:  кто действительно хочет побеждать в конкурсах и эффективно управлять проектами
# Sentence:  должен прежде всего учиться
# Sentence:
# Sentence: Насколько эффективна холодная сварка
# Sentence:
# Sentence: Если она всего лишь недостаточно прочная
# Sentence:  сыпется песком
# Sentence:  поверхность необходимо укрепить водоразбавимым акриловым грунтом
# Sentence:
# Sentence: Какой способ надёжнее
# Sentence:
# Sentence: Штукатурка
# Sentence:  шпаклёвка
# Sentence:  грунтовка и только после этого
# Sentence:
# Sentence:  окончательная отделка
# Sentence:
# Sentence: Во всех остальных случаях вопрос об использовании сухих смесей сегодня не стоит
# Sentence:
# Sentence: При использовании готового продукта бетономешалка или другой специальный инструмент для замеса вам не понадобятся
# Sentence:
# Sentence: Разница в цене между аналогичными отечественными и импортными материалами порой доходит до 50%
# Sentence:
# Sentence: Качество
# Sentence:
# Sentence:  на порядок выше
# Sentence:  цены
# Sentence:
# Sentence:  соответствующие
# Sentence:
# Sentence: Не менее важная «деталь» отделки
# Sentence:
# Sentence:  грунтовка
# Sentence:
# Sentence: Проанализировать все виды сухих смесей в рамках одной статьи невозможно
# Sentence:  их бесчисленное множество
# Sentence:
# Sentence: В ванной комнате осыпалась плитка
# Sentence:  причём только с одной стены
# Sentence:
# Sentence: Что же с ней можно сделать
# Sentence:
# Sentence: Если этим пренебречь
# Sentence:  отделка будет радовать вас недолго
# Sentence:
# Sentence: Мы предлагаем обзоры кровельных и стеновых материалов
# Sentence:  экспонатов
# Sentence:  заслуживающих пометки «новое
# Sentence: »
# Sentence:  репортаж с дизайнерского субботника
# Sentence:  консультацию специалиста по выставочной деятельности
# Sentence:  мнения профессионалов
# Sentence: строителей о выставке
# Sentence:
# Sentence: С воскресенья машины со столичными номерами занимают очередь за афонинским кирпичом
# Sentence:
# Sentence: Зачем бы «Керме» 40 видов кирпичей
# Sentence:  когда и самый обыкновенный шёл на ура
# Sentence:
# Sentence: И то верно
# Sentence:
# Sentence: Поэтому предложение немецких строителей не кажется запредельным
# Sentence:
# Sentence: А их
# Sentence: то в этот раз было очень мало
# Sentence:
# Sentence: Если на выставках прошлых лет такие фирмы
# Sentence:  как «Регион»
# Sentence:  «Мастер Люкс» и «Саксэс»
# Sentence:  не имели своего стенда
# Sentence:
# Sentence:  принимали участие совместно с другими фирмами
# Sentence:  то нынче они выступают с самостоятельными и весьма привлекательными экспозициями
# Sentence:
# Sentence: Но тогда мы о финской технологии
# Sentence:  к сожалению
# Sentence:  не знали
# Sentence:
# Sentence: Но зато мы почувствовали
# Sentence:  что вызвали интерес у представителей вашей страны
# Sentence:
# Sentence: Мы выставили этот материал на пробу
# Sentence:
# Sentence:
# Sentence:  комментирует главный инженер фирмы Александр Молев
# Sentence:
# Sentence:
# Sentence:  может
# Sentence:  кто и заинтересуется
# Sentence:
# Sentence: В этом особый резон
# Sentence:  ведь фирма только в этом году
# Sentence:  получив строительную лицензию
# Sentence:  начала самостоятельно осуществлять монтажные работы
# Sentence:
# Sentence: Помимо этого
# Sentence:  суду необходимо установить
# Sentence:  а сторонам по делу доказать следующие обстоятельства
# Sentence:
# Sentence:
# Sentence:  по какой причине гражданин выехал из жилого помещения
# Sentence:
# Sentence:
# Sentence:  характер отсутствия в нём
# Sentence: постоянный или временный
# Sentence:
# Sentence:
# Sentence:
# Sentence:  желает ли выехавший возвратиться в жилое помещение для проживания в нём
# Sentence:  если да
# Sentence:  то через какой период времени
# Sentence:
# Sentence:
# Sentence:  отказался ли гражданин от своих прав на жилое помещение
# Sentence: может
# Sentence:  он безразлично относится к сохранению таких прав
# Sentence:
# Sentence:
# Sentence:
# Sentence:  приобрел ли выехавший право на другое жилое помещение и постоянно ли проживает в нём
# Sentence:
# Sentence: На мой взгляд
# Sentence:  нет ничего предосудительного в том
# Sentence:  что человек
# Sentence:  не имеющий юридического образования
# Sentence:  не видит разницы между исками о признании гражданина утратившим право пользования жилым помещением от исков о признании гражданина не приобретшим это право
# Sentence:
# Sentence: Истица реализовала данное право
# Sentence:  изменила свои исковые требования
# Sentence:  которые после судебного разбирательства были удовлетворены
# Sentence:
# Sentence: Работа архитекторов видна всем
# Sentence:  вот они
# Sentence:  их дома
# Sentence:  здания
# Sentence:
# Sentence: Поэтому и поспешил к вам сюда сегодня»
# Sentence:
# Sentence: Дворец спорта
# Sentence:  24 мая
# Sentence:
# Sentence: Цена билетов 15
# Sentence:  45 руб
# Sentence:  ТЕАТР ДРАМЫ
# Sentence: 33
# Sentence:  16
# Sentence:  66
# Sentence:  35
# Sentence:  67
# Sentence:  33
# Sentence:  19
# Sentence:  51
# Sentence:  73
# Sentence:  А
# Sentence:  Вампилов
# Sentence:
# Sentence: 23 мая
# Sentence:  18
# Sentence:  00
# Sentence:
# Sentence: Цена балетов 20
# Sentence:  100 руб
# Sentence:  ТЕАТР ЮНОГО ЗРИТЕЛЯ
# Sentence: 35
# Sentence:  07
# Sentence:  85
# Sentence:
# Sentence: Цена билетов
# Sentence:
# Sentence:  8
# Sentence:  35 руб
# Sentence:  ТЕАТР КУКОЛ
# Sentence: 34
# Sentence:  09
# Sentence:  22
# Sentence:  А
# Sentence:  Абу
# Sentence: Бакар
# Sentence:
# Sentence: Комедийный боевик «Случайный шпион»
# Sentence:
# Sentence: Цена билетов 20
# Sentence:  100 руб
# Sentence:
# Sentence: 20
# Sentence:  10
# Sentence:  22
# Sentence:  40
# Sentence:  24
# Sentence:  30 мая
# Sentence:  9
# Sentence:  30
# Sentence:  12
# Sentence:  10
# Sentence:  14
# Sentence:  50
# Sentence:  17
# Sentence:  30
# Sentence:  20
# Sentence:  10
# Sentence:  22
# Sentence:  40
# Sentence:
# Sentence: Киносеансы уточняйте по указанным телефонам
# Sentence:
# Sentence: Сегодня
# Sentence:  20 мая
# Sentence:  ожидается холодная погода
# Sentence:
# Sentence: Днём до 20
# Sentence:  25°
# Sentence:
# Sentence: На ткани находится масса из смеси смолы
# Sentence:  живицы
# Sentence:  коричневого испанского красителя
# Sentence:  пчелиного воска и льняного масла
# Sentence:  которая наносится в горячем состоянии»
# Sentence:
# Sentence:  это описание относится к середине восемнадцатого века
# Sentence:
# Sentence: Такой линолеум отличается не только современным дизайном
# Sentence:  но и высокими прочностными характеристиками
# Sentence:  даёт меньшую усадку
# Sentence:  более долговечен
# Sentence:
# Sentence: Между прочим в каждой квартире есть помещение
# Sentence:  где стоит отказаться от бытового линолеума
# Sentence:
# Sentence: В среднем сантиметр стяжки сохнет в течение недели
# Sentence:  при толщине более четырёх сантиметров каждый последующий сантиметр добавляет две недели
# Sentence:
# Sentence: Рельефная поверхность
# Sentence:
# Sentence:  не лучшее основание для линолеума
# Sentence:  на нём будет виден каждый шов
# Sentence:  к тому же покрытие быстро изотрётся
# Sentence:
# Sentence: ДВП
# Sentence:  ДСП
# Sentence:  бетонное основание
# Sentence: если оно предварительно покрашено
# Sentence:  перед наклейкой грунтовать необязательно
# Sentence:  а вот в случае с ГВЛ без грунтовки не обойтись
# Sentence:
# Sentence: Затем прикладывают линейку и прорезают острым ножом уложенные внахлест оба полотнища
# Sentence:
# Sentence: Чего боится линолеум
# Sentence:
# Sentence: Информация о работе комиссии по этике НГР
# Sentence:  которую возглавляет Максим Виноградский
# Sentence:  директор АН «Мегаполис»
# Sentence:  дала повод для серьёзного разговора № о работе фирм
# Sentence:
# Sentence: Если бы в договоре было чётко оговорено
# Sentence:  что обязан оплатить клиент при расторжении договора
# Sentence:  при отказе от покупки или продажи квартиры
# Sentence:  какие расходы фирмы компенсировать
# Sentence: на сбор документов
# Sentence:  на рекламу квартиры
# Sentence:
# Sentence:  то конфликтов было бы меньше
# Sentence:
# Sentence: В общем
# Sentence:  получается
# Sentence:  что основная причина конфликтов
# Sentence:
# Sentence:  в несовершенстве работы самих фирм
# Sentence:  а иногда в непонимании
# Sentence:  кто они и чем занимаются
# Sentence:  то ли продают товар
# Sentence:  то ли оказывают услугу
# Sentence:
# Sentence: Кроме того
# Sentence:  решение конфликтной комиссии для сертифицированных фирм носит обязательный характер
# Sentence:
# Sentence: Опрос проводила Ирина ВАРЕНЦОВА
# Sentence: ОТВЕЧАЙ
# Sentence:
# Sentence:  И ВЫИГРАЕШЬ
# Sentence:
# Sentence: 2
# Sentence:
# Sentence: САДОВУЮ МЕБЕЛЬ из хвойных пород предлагает магазин «Банбас»
# Sentence:
# Sentence: ДАЧНАЯ КОРЗИНКА
# Sentence: ДИФФЕНБАХИИ
# Sentence:
# Sentence: НАСОС «Агидель»
# Sentence:  ЭЛЕКТРООПРЫСКИВАТЕЛЬ
# Sentence:
# Sentence: ОЛЕАНДР
# Sentence:  2 шт
# Sentence:
# Sentence: САЖЕНЦЫ АКТИНИДИИ
# Sentence:  12 морозоустойчивых сортов винограда для северной зоны
# Sentence:  раннего
# Sentence:  среднего
# Sentence:  очень раннего срока созревания
# Sentence: 178 руб
# Sentence:
# Sentence:
# Sentence:  принимаем заявки
# Sentence:
# Sentence: Впрочем
# Sentence:  это был не участок
# Sentence:  а кусок болота
# Sentence:
# Sentence: А глядя на буйную
# Sentence:  пряно пахнущую зелень
# Sentence:
# Sentence:  и петрушку
# Sentence:  и укроп
# Sentence:  и лук
# Sentence:  невольно представляешь себе дымящийся шашлык
# Sentence:
# Sentence:
# Sentence:
# Sentence: Каждый
# Sentence:
# Sentence:  индивидуальность
# Sentence:
# Sentence: Правда
# Sentence:  иногда встречаются среди представителей этого типа заборы «слабое звено
# Sentence:
# Sentence: с проделанной в сетке дырой или невзначай отвалившейся дощечкой
# Sentence:
# Sentence:
# Sentence: В качестве прочих заборных прибамбасов можно ещё указать почтовые ящики и кошек
# Sentence:
# Sentence: Ведь если я
# Sentence:  Растеряев
# Sentence:  представитель «Нижегородского дома»
# Sentence:  выйду с законодательной инициативой
# Sentence:  кто со мной будет разговаривать
# Sentence:
# Sentence: Как
# Sentence:  например
# Sentence:  в Москве
# Sentence:  член Союза московских строителей
# Sentence:
# Sentence:  марка
# Sentence:
# Sentence: Сейчас мы создаём на базе Дома строителей
# Sentence: ул
# Sentence:  Рождественская
# Sentence:  45
# Sentence:  информационный центр
# Sentence:  который начнёт собирать базу данных по профессиям
# Sentence:  организациям
# Sentence:  материалам
# Sentence:
# Sentence: Будем оказывать помощь и в составлении бизнес
# Sentence: планов и анализировать новые технологии
# Sentence:
# Sentence: А поскольку в союзе будут работать специалисты
# Sentence:
# Sentence:  профессионалы рекламного дела
# Sentence:  все стенды приобретут привлекательный вид
# Sentence:  ведь далеко не каждое предприятие
# Sentence:  желающее участвовать в выставке
# Sentence:  может финансово и организационно осилить такую работу
# Sentence:
# Sentence: Итак
# Sentence:  Союз нижегородских строителей
# Sentence:
# Sentence:  это
# Sentence:
# Sentence:
# Sentence:
# Sentence: П
# Sentence:  Новиков
# Sentence:
# Sentence: До 23
# Sentence:  30 вход для дам
# Sentence:  бесплатный
# Sentence:
# Sentence: 22 сентября
# Sentence:  22
# Sentence:  00
# Sentence:
# Sentence: Программа
# Sentence:  Шопен
# Sentence:  Чайковский
# Sentence:
# Sentence: Цена билетов 4
# Sentence:  6 рублей ВЫСТАВОЧНЫЙ КОМПЛЕКС
# Sentence: 39
# Sentence:  09
# Sentence:  71
# Sentence:
# Sentence: Экскурсионное обслуживание
# Sentence:
# Sentence:  50 рублей
# Sentence:
# Sentence: Цена билетов 200
# Sentence:  500 рублей
# Sentence:
# Sentence: 23 и 24 сентября
# Sentence:  19
# Sentence:  00
# Sentence:
# Sentence:  Альдо ди Бенедетти
# Sentence:
# Sentence: Цена билетов 10
# Sentence:  30 рублей Тир
# Sentence: для взрослых
# Sentence:
# Sentence:  1 выстрел
# Sentence:
# Sentence:  2 рубля
# Sentence: ОТВЕЧАЙ
# Sentence:
# Sentence:  И ВЫИГРАЕШЬ
# Sentence:
# Sentence: Надеемся
# Sentence:  он поможет вырастить вам крепкую рассаду и хороший урожай
# Sentence:
# Sentence: 21 сентября
# Sentence:  СУББОТА Рыбы до 20
# Sentence:  12 Овен
# Sentence:  полнолуние в 17
# Sentence:  00
# Sentence:
# Sentence: Теперь можете выбрать
# Sentence:
# Sentence: Например
# Sentence:  о том
# Sentence:  что на привокзальной площади когда
# Sentence: то стоял Дом культуры «Спартак» с кинозалом
# Sentence:
# Sentence: Кстати
# Sentence:  новый путеводитель Евгения Стрелкова «Техногенез»
# Sentence: можно купить в магазине «Дирижабль»
# Sentence:  знакомит не только с промышленными зданиями
# Sentence:  но напоминает о людях
# Sentence:  сделавших немало для того
# Sentence:  чтобы наш край был богаче
# Sentence:
# Sentence: Подобные материалы имеют толщину 3
# Sentence:  5 миллиметров и обычно продаются в рулонах по 10 квадратных метров
# Sentence:
# Sentence: Эта мастика имеет все необходимые сертификаты и рекомендована для работы с гипсоволокнистыми листами
# Sentence:
# Sentence: Можно закрыть стену гипсоволокнистыми листами
# Sentence:  тогда изнутри всё будет в порядке
# Sentence:  но стена по
# Sentence: прежнему будет мокнуть
# Sentence:  гнить и постепенно разрушаться
# Sentence:
# Sentence: На вопросы отвечали
# Sentence:  Сергей Марков
# Sentence: ООО «РЯД»
# Sentence:
# Sentence:  Георгий Смирнов
# Sentence: ЗАО «Еврогипс»
# Sentence:
# Sentence:  Игорь Печенов
# Sentence: ЗАО «Новтекс»
# Sentence:
# Sentence:  Алексей Мартынов
# Sentence: компания «Ордер»
# Sentence:
# Sentence:
# Sentence: Вот уже несколько лет компания осваивает территорию Нижегородского района между улицами Новая
# Sentence:  Белинского и Славянская
# Sentence:
# Sentence: То есть несущий каркас
# Sentence:
# Sentence:  колонны и ригели
# Sentence:
# Sentence:  перекрывается плитами
# Sentence:  которые используются сначала как опалубочный материал
# Sentence:  а после бетонирования становятся несущим
# Sentence:  связывающим каждый уровень материалом
# Sentence:
# Sentence: Это исключение или правило
# Sentence:
# Sentence: Что значит «администрация города закладывает рентабельность»
# Sentence:
# Sentence: Это так только кажется со стороны
# Sentence:
# Sentence: Если бы я имел возможность свои ресурсы вложить в строительство на начальном этапе
# Sentence:  тогда понятно
# Sentence:  построил
# Sentence:  заработал
# Sentence:  рассчитался
# Sentence:
# Sentence: Можно
# Sentence:  построив один
# Sentence: два дома
# Sentence:  действительно развиться
# Sentence:  подкупить новые технологии
# Sentence:  технику и т
# Sentence:  д
# Sentence:  В этом плане 1998 год очень хорошим был для строителей
# Sentence:  а с тех пор никто никак опомниться не может
# Sentence:
# Sentence: Условно на это потребуется 20
# Sentence:  30 млн рублей
# Sentence:
# Sentence: Пять домов
# Sentence:
# Sentence:  50 миллионов
# Sentence:  и мы закрыли проблему расселения и строительства всех сетей в этом микрорайоне
# Sentence:
# Sentence: Безусловно
# Sentence:
# Sentence: Награждение лауреатов проходило в Москве в здании Манежа в субботу
# Sentence:  11 октября
# Sentence:  когда этот номер газеты был уже сверстан
# Sentence:
# Sentence: Главой администрации Сормовского района назначен Андрей Ковба
# Sentence: бывший начальник цеха ОАО «Красное Сормово»
# Sentence:  директор сормовского МУП «Дорожник»
# Sentence:
# Sentence:
# Sentence: Дилижанс
# Sentence: авто
# Sentence:
# Sentence:
# Sentence:  общественная организация
# Sentence:  представляющая интересы владельцев и водителей полутора сотен маршрутных такси
# Sentence:
# Sentence: Текучка среди частников была высока
# Sentence:
# Sentence: Видимо
# Sentence:  по мнению следствия
# Sentence:  это не является давлением на следствие и свидетелей
# Sentence:
# Sentence: Региональное отделение партии
# Sentence:  Яблоко
# Sentence:
# Sentence:  не отличающееся обычно большой активностью
# Sentence:  стало объектом внимания со стороны различных политических и финансовых групп
# Sentence:
# Sentence: Партия
# Sentence:  Яблоко
# Sentence:
# Sentence:  несмотря на небольшой электорат
# Sentence:  имеет свою фракцию в Госдуме и хорошо раскрученный бренд
# Sentence:
# Sentence: Ожидается
# Sentence:  что в рамках рассмотрения этого вопроса будет пересматриваться персональный состав бюро
# Sentence:
# Sentence: Техасцы действительно очень гордятся своим штатом
# Sentence:  и лучше их не задевать
# Sentence:  намекая
# Sentence:  например
# Sentence:  на то
# Sentence:  что их штат
# Sentence:
# Sentence:  провинция
# Sentence:
# Sentence: Наверное
# Sentence:  настоящих ковбоев в Америке встретить сложнее
# Sentence:  чем настоящих казаков в России
# Sentence:
# Sentence: Больше всего людей приходят на Pioneer Plaza
# Sentence: Сквер Пионеров
# Sentence:
# Sentence:  где расположена большая скульптурная группа из множества медных быков
# Sentence:  ведомых на водопой медными ковбоями
# Sentence:
# Sentence: Дети в Америке действительно не ограничены практически ни в чём
# Sentence:
# Sentence: Эти особняки состоятельных техасцев
# Sentence: тут уже не скажешь
# Sentence:  дома
# Sentence:
# Sentence:
# Sentence:  именно особняки
# Sentence:  расположены недалеко от огромного Далласского ботанического сада под открытым небом
# Sentence:
# Sentence: Даже сами здания в университетском городке очень часто построены в средневековом стиле и отличаются от остальной части города
# Sentence:
# Sentence: В каждой комнате обычно есть розетка для выхода в Интернет
# Sentence: чаще всего бесплатная
# Sentence:  и телефон
# Sentence: с автоответчиком
# Sentence:  на который рассылаются все университетские новости
# Sentence:
# Sentence:
# Sentence: В больших университетских городках можно жить
# Sentence:  не выезжая
# Sentence:  годами так как там есть всё
# Sentence:  что душе угодно
# Sentence:  и парикмахерская
# Sentence:  и кинотеатр
# Sentence:  и концертный зал
# Sentence:  и театр
# Sentence:
# Sentence: Задерживать сдачу работ без предупреждения не рекомендуется
# Sentence:  но к уважительным причинам профессора относятся уважительно
# Sentence:
# Sentence: На самых разных уровнях заговорили об ответственности за незаконное изготовление и сбыт алкоголя
# Sentence:
# Sentence: Впрочем
# Sentence:  более подробно надеемся рассказать о проекте после очередного заседания областной думы
# Sentence:
# Sentence: В первую очередь
# Sentence:  согласно тексту законопроекта
# Sentence:  государство будет более жёстко контролировать поступления от акцизов
# Sentence:
# Sentence: Впервые в истории саратовской журналистики сумма иска по возмещению морального вреда составила 3 миллиона рублей
# Sentence:
# Sentence: Иск Бондара подан на статью Крутова в
# Sentence:  Неделе области
# Sentence:
# Sentence:  хотя в
# Sentence:  Богатее
# Sentence:  публиковалось немало критических материалов этого же журналиста о деятельности областного прокурора
# Sentence:
# Sentence: Во
# Sentence: вторых
# Sentence:  в своём иске Бондар просит суд взыскать компенсацию морального вреда с ответчиков и перечислить в
# Sentence:  детский дом Вольского района Саратовской области
# Sentence:
# Sentence:
# Sentence: В благодарность за поддержку городская администрация стала снабжать прокурорские структуры
# Sentence:  дарёными
# Sentence:  иномарками
# Sentence:  мебелью
# Sentence:
# Sentence: С учётом этого я обязан нести повышенную ответственность по соблюдению не только правовых
# Sentence:  но и моральных норм
# Sentence:
# Sentence:
# Sentence: Служебные помещения прокуратур Ленинского
# Sentence:  Октябрьского
# Sentence:  Фрунзенского районов и городской прокуратуры больше напоминают офисы преуспевающих коммерческих фирм
# Sentence:
# Sentence: Это совещание стало уже третьим выездным совещанием
# Sentence:  проводимым в различных районах при участии представителей малого бизнеса
# Sentence:
# Sentence: Выездные совещания были организованы
# Sentence:  чтобы изучить ситуацию на местах
# Sentence:
# Sentence: Но если с теоретической подготовкой у министра всё в порядке
# Sentence:  то от жизненных реалий он оказался несколько оторван
# Sentence:
# Sentence: Справедливой критике подверглись проверяющие органы
# Sentence:  сурово карающие за нарушение закона о применении контрольно
# Sentence: кассовых машин
# Sentence:
# Sentence: Например
# Sentence:  единственное фотоателье в рабочем посёлке при нынешнем уровне ЕНВД едва сводит концы с концами
# Sentence:
# Sentence: Рынок не работал
# Sentence:
# Sentence: Впервые информация об этом контракте появилась на информационном сайте ГТРК
# Sentence:  Саратов
# Sentence:  28 февраля 2003 года
# Sentence:
# Sentence: Таким образом
# Sentence:  можно констатировать
# Sentence:  что побит местный рекорд по оценке морального вреда в 3 млн рублей
# Sentence:  продемонстрированный в прошлом номере прокурором области Анатолием Бондаром
# Sentence:
# Sentence: Летом же население грезит о том
# Sentence:  чтобы та же горячая водичка текла из крана
# Sentence:  давая возможность омовения тела
# Sentence:  разгорячённого зноем
# Sentence:  поездками в общественном транспорте и копанием на шести сотках
# Sentence:  гордо именуемых в народе дачей
# Sentence:
# Sentence: Убытки в каждый летний месяц у неё равны 76 тыс
# Sentence:  рублям
# Sentence:
# Sentence: Свёл их друг с другом и заодно с представителем сидящих без горячей воды житель с улицы Емлютина депутат Леонид Писной
# Sentence:
# Sentence: Хочется верить
# Sentence:  что трубы
# Sentence:  связывающие системы ГВС котельных и магистрали централизованного ГВС
# Sentence:  появятся ещё этим летом
# Sentence:
# Sentence: Добровольные признания в совершенных преступлениях происходят крайне редко
# Sentence:
# Sentence: Как обычно бывает в таких случаях
# Sentence:  оперативники занялись сбором сведений о личности убитой
# Sentence:
# Sentence: Рассказ Виктора подтвердил эту версию
# Sentence:
# Sentence: Впечатлительный Виктор проецировал эту ситуацию на себя
# Sentence:
# Sentence: Попытка пересчитать места другими наблюдателями привела к такому же результату
# Sentence:
# Sentence: И хотя его связь с администрацией рынка не доказана
# Sentence:  сам факт готовности уплатить такую сумму говорит о дефиците мест
# Sentence:
# Sentence: До сих пор проверки деятельности фонда серьёзных последствий не имели
# Sentence:  возможно
# Sentence:  благодаря тому
# Sentence:  что главным бухгалтером числится Валентина Солодкова
# Sentence:
# Sentence:  тёща мэра
# Sentence:
# Sentence: Согласно договорам фонд передаёт предпринимателям в аренду определённые площади без указания торговых мест
# Sentence:
# Sentence: В среднем она теперь составляет 2150 рублей за торговое место
# Sentence:
# Sentence: Схема
# Sentence:  описанная в данной статье
# Sentence:  могла бы послужить некоторым предпринимателям образцом не только ухода от налогов
# Sentence:  но и от ответственности
# Sentence:
# Sentence: По милицейской логике
# Sentence:  пьяного спокойнее изолировать до вытрезвителя
# Sentence:  чем позволить ему самостоятельно добираться домой
# Sentence:
# Sentence: Часто травму получают в драках
# Sentence:  неистраченный пыл борьбы в сочетании с винными парами и приводит пациентов к безобразным выходкам
# Sentence:
# Sentence: После этого постовые начинали задерживать граждан даже в лёгкой стадии опьянения
# Sentence:
# Sentence: Возможно
# Sentence:  это и стало одной из причин
# Sentence:  по которой милиция легко согласилась на закрытие вытрезвителей
# Sentence:
# Sentence: Мэрия пыталась обосновать сделку необходимостью срочно получить средства для расчётов с энергетиками
# Sentence:
# Sentence: Вопреки правилам КУИ рассматривал заявку в течение 4
# Sentence: х месяцев
# Sentence:
# Sentence: Казалось бы
# Sentence:  после получения столь однозначного судебного решения КУИ должен начать приватизацию помещения
# Sentence:
# Sentence: Так что
# Sentence:  возможно
# Sentence:  в ближайшее время в историю административного управления городом будет вписана новая страница
# Sentence:
# Sentence:  понуждение через суд выполнять свои служебные обязанности
# Sentence:
# Sentence: По вашим наблюдениям
# Sentence:  менялся ли ТЮЗ в эти годы
# Sentence:
# Sentence: Так
# Sentence:  спектакль «Недоросль» по пьесе Фонвизина со стихами Юлия Кима воспринимался в годы застоя как острая политическая сатира
# Sentence:
# Sentence: Выяснилось
# Sentence:  что нашим оружием можно принести немало зла
# Sentence:  если неразумно им пользоваться
# Sentence:
# Sentence: Мы перестали реагировать на пролитую кровь
# Sentence:  а раньше это всегда было настоящим шоком
# Sentence:
# Sentence: Поэтому я считаю
# Sentence:  что необходимо занимать тренировкой детских душ
# Sentence:  что мы и стараемся делать в каждой пьесе
# Sentence:  даже развлекательной
# Sentence:
# Sentence: Они
# Sentence:  с одной стороны
# Sentence:  не терпят фальши
# Sentence:  а с другой
# Sentence:
# Sentence:  очень доверчивы
# Sentence:  поэтому зачастую их очень легко купить
# Sentence:
# Sentence: Какие ещё спектакли сейчас находятся в работе театра
# Sentence:
# Sentence: Можно сказать
# Sentence:  что все участники фестиваля получили новый опыт
# Sentence:
# Sentence: Это очень важно для меня при создании спектакля
# Sentence:
# Sentence:  быть «обожжённым» темой
# Sentence:
# Sentence: Также и мы
# Sentence:  боремся за души
# Sentence:  но при этом являемся такими же грешниками
# Sentence:  как и все
# Sentence:
# Sentence: Организаторы фестиваля
# Sentence:
# Sentence:  правительство
# Sentence:  министерство культуры области и собственно цирк в лице директора Ивана Кузьмина на прошедшей 8 сентября пресс
# Sentence: конференции раскрыли некоторые подробности
# Sentence:
# Sentence: 16
# Sentence:  17
# Sentence:  1819 сентября
# Sentence:
# Sentence:  будни фестиваля
# Sentence:  участники представят зрителям и жюри свои программы
# Sentence:
# Sentence: Символический
# Sentence:  Оскар
# Sentence:  фестиваля
# Sentence:
# Sentence:  металлическая статуэтка
# Sentence:
# Sentence:  изображающая трех лошадок
# Sentence:  повторяет эмблему Саратовского цирка
# Sentence:
# Sentence: А мы
# Sentence:  со своей стороны
# Sentence:  обещаем всем читателям газеты
# Sentence:  Богатей
# Sentence:
# Sentence:  с билетами и без
# Sentence:  подробные отчёты о фестивале
# Sentence:
# Sentence: Соответственно
# Sentence:  как упоминается в программе
# Sentence:  на конкурсной основе и распределялись средства для
# Sentence:  производства и тиражирования материалов социально значимой тематики
# Sentence:
# Sentence:
# Sentence: По данным тех же социологов
# Sentence:  36 процентов саратовцев и 15 процентов жителей районов считают
# Sentence:  что получают через СМИ мало
# Sentence:  полезной информации
# Sentence:
# Sentence:
# Sentence: Судите сами
# Sentence:
# Sentence: Стоит отметить скромность нашего министра печати Игоря Никифорова
# Sentence:  принадлежащей ему газете
# Sentence:  АиФ Саратов
# Sentence:  правительство с областной думой выделили всего 250 тысяч рублей
# Sentence:
# Sentence:  меньше
# Sentence:  чем
# Sentence:  Униклассной газете
# Sentence:
# Sentence:  Телеком ТВ
# Sentence:
# Sentence:  и столько же
# Sentence:  сколько ИВК
# Sentence:  Солнечный
# Sentence:
# Sentence:
# Sentence: Подписка вот который год съеживается
# Sentence:
# Sentence: Отчасти из
# Sentence: за недостаточной массы платёжеспособных читателей
# Sentence:  отчасти из
# Sentence: за того
# Sentence:  что качественная информация стоит дорого
# Sentence:
# Sentence: Больше всего покупают кроссворды
# Sentence:  телегиды и развлекаловку
# Sentence: Лидерами по тиражам в 2002 г
# Sentence:  были кроссвордные журналы
# Sentence:  доля которых на российском рынке составила 14
# Sentence:  9%
# Sentence:
# Sentence: По мнению Жаворонского
# Sentence:  его специально выбрали из общего потока машин
# Sentence:
# Sentence: Сразу после Гор ГАИ он отправился в бюро судебно
# Sentence: медицинской экспертизы
# Sentence:
# Sentence: Игорь Дмитриевич сделал своеобразный среднесрочный прогноз политического курса мэрии
# Sentence:
# Sentence:  Через пару лет они раздадут всё
# Sentence:  что можно
# Sentence:  под стоны и вопли
# Sentence:  что им не дают денег
# Sentence:
# Sentence:
# Sentence: На прошлой неделе в актовом зале десятого корпуса СГУ
# Sentence:  который так привык к различного рода зрелищным мероприятиям
# Sentence:  подготовленным студентами
# Sentence:  состоялась ещё одно
# Sentence:  правда
# Sentence:  гораздо более серьёзное
# Sentence:  шоу
# Sentence:
# Sentence:  выборы нового ректора университета
# Sentence:  который вступит в свои полномочия с первого ноября
# Sentence:
# Sentence: Среди важнейших принципов работы декан мехмата выделил демократизм
# Sentence:  информатизацию и государственность
# Sentence:  патриотизм
# Sentence:
# Sentence: Леонид Аркадьевич ответил
# Sentence:  что не идеализирует работу Трубецкова
# Sentence:  но при этом не собирается
# Sentence:  мазать прежний ректорат чёрной краской
# Sentence:
# Sentence:
# Sentence: После делегатов также выступил Дмитрий Трубецков
# Sentence:
# Sentence: Старая Москва
# Sentence: Это и протоколы
# Sentence:  и многие статистические данные
# Sentence:  которые порой ужасают
# Sentence:  а порой и веселят читателя
# Sentence:
# Sentence: Однако избирательные технологии совершенствовались
# Sentence:  и теперь
# Sentence:  отказавшись от конкретных
# Sentence:  заверений в почтении
# Sentence:
# Sentence:  мало кто из претендентов на должность депутата не стремится найти для себя
# Sentence: разумеется
# Sentence:  с помощью многочисленных специалистов в этой области
# Sentence:  единственное и неповторимое словосочетание
# Sentence: т
# Sentence:  н
# Sentence:
# Sentence:  слоган
# Sentence:
# Sentence:
# Sentence:  который помог бы ему решительно повлиять на умы и души избирателей в свою пользу
# Sentence:
# Sentence: И опять непонятно
# Sentence:  с кем бой
# Sentence:
# Sentence: Оппоненты
# Sentence:  правда
# Sentence:  не были посрамлены
# Sentence:  но
# Sentence:  как часто бывает
# Sentence:  эффект от их высказываний может получиться обратный
# Sentence:  т
# Sentence:  е
# Sentence:  в пользу борца с
# Sentence:  главным злом
# Sentence:  Саратовской области
# Sentence:
# Sentence: Однако есть и другие
# Sentence:  более поздние
# Sentence:  примеры из жизни нашего героя
# Sentence:
# Sentence: Удостоверения
# Sentence:  справки
# Sentence:  свидетельства
# Sentence:  необходимые и не очень
# Sentence:  для получения их мы проводим долгие часы ожидания перед чиновничьими кабинетами
# Sentence:  не всегда понимая зачем нужен очередной документ
# Sentence:
# Sentence: Больше двух лет получали Пильгановы пенсию
# Sentence:
# Sentence: Дело передали в следственный отдел РУВД
# Sentence:
# Sentence: Ведь факт отцовства признан совсем недавно
# Sentence:  значит
# Sentence:  два года она получала пенсии незаконно
# Sentence:
# Sentence: Сделать это она отказалась
# Sentence:
# Sentence: После того
# Sentence:  как в начале года Высший арбитражный суд России вынес окончательное решение о ликвидации ЗАО «МНВК ТВ
# Sentence: 6 Москва»
# Sentence:  160 региональных партнёров этой компании
# Sentence:  лишившись в одночасье сигнала центрального канала
# Sentence:  вынуждены были бороться за выживание в весьма непростых условиях
# Sentence:
# Sentence: Виталий Аркадьевич хотел найти партнёра среди каналов с высоким рейтингом
# Sentence:
# Sentence:  Тем не менее так и получилось
# Sentence:
# Sentence: Проверка на прочность
# Sentence: Совсем скоро пройдёт съезд региональных партнёров ЗАО «Шестой канал
# Sentence: СМИ ТВС
# Sentence: »
# Sentence:  на котором станет ясно
# Sentence:  на каких условиях будут сотрудничать центральный и провинциальные каналы
# Sentence:
# Sentence: Ввиду явного преимущества
# Sentence: Володя серьёзно занимался боксом и
# Sentence:  одерживая одну за другой победу на ринге
# Sentence:  скорее
# Sentence:  видел себя тренером
# Sentence:
# Sentence: Тернистая тропа шоу
# Sentence: бизнеса тоже не привлекала
# Sentence:
# Sentence:  немало поездив по стране
# Sentence:  Володя прекрасно понимал
# Sentence:  что серьёзно работать в этой сфере можно только в Москве или
# Sentence:  по крайней мере
# Sentence:  в Питере
# Sentence:
# Sentence: Результаты тестирования физических и умственных данных оказались довольно высокими
# Sentence:
# Sentence:  в итоге поступило предложение поступить на службу
# Sentence:
# Sentence: Предметом обогащения стали дефицитные джинсы
# Sentence:  которые пользовались неизменной популярностью в любое время года и позволяли заработать от 30 до 100 процентов чистой прибыли с каждой пары
# Sentence:
# Sentence: В свободное время Владимир по
# Sentence: прежнему увлекался музыкой и даже помогал своему другу Руслану Татаринцеву отбирать участников рок
# Sentence: н
# Sentence: ролльных фестивалей «Самый плохой»
# Sentence:  проходивших на базе Дома молодёжи
# Sentence:
# Sentence: С распростёртыми объятиями Аверина ждали на заводе по производству силикатного кирпича
# Sentence:  где он проходил практику
# Sentence:  но работа по характеру была довольно рутинной
# Sentence:  а Владимиру всегда хотелось чего
# Sentence: то динамичного
# Sentence:  «Сидеть и тупо перебирать бумажки
# Sentence:
# Sentence:  это не моё»
# Sentence:
# Sentence: Места в своих отделах Аверину по старой дружбе предложили знакомые по институту Борисевич и Багаев
# Sentence:
# Sentence: В итоге
# Sentence:  вслед за Борисевичем и Багаевым
# Sentence:  в 1996 году Владимир
# Sentence:  потеряв в зарплате
# Sentence:  но
# Sentence:  обретя возможность перспектив
# Sentence:  начал работать в «Солидарности»
# Sentence:
# Sentence: Новое
# Sentence:
# Sentence:  это всегда интересно»
# Sentence:
# Sentence:
# Sentence:  отмечает Аверин
# Sentence:
# Sentence: К трудоголикам Владимир себя не относит
# Sentence:  но если нужно
# Sentence:  Аверин не считает за труд поработать и до одиннадцати вечера
# Sentence:
# Sentence: 19
# Sentence:  04
# Sentence:  2002
# Sentence: Тут уж либо дано
# Sentence:  либо нет
# Sentence:
# Sentence: В этом случае можно посоветовать одно
# Sentence:
# Sentence:  пора умнеть
# Sentence:
# Sentence: Сергей ПЕТУХОВ
# Sentence:  генеральный директор РСЦ
# Sentence:  Мабис
# Sentence:
# Sentence: Если же слышу иронию в свой адрес
# Sentence:  стараюсь удалиться
# Sentence:  не слушать
# Sentence:  потому что это
# Sentence:  как ни крути
# Sentence:  неприятно
# Sentence:
# Sentence: Я всегда смеюсь над собой
# Sentence:  даже в компании друзей
# Sentence:
# Sentence: Наверное
# Sentence:  сильно задевают такие вещи излишне амбициозных и обидчивых людей
# Sentence:
# Sentence: Я нормально отношусь и к подтруниванию надо мной друзей
# Sentence:  если
# Sentence:  конечно же
# Sentence:  в этом нет скрытой злости
# Sentence:
# Sentence: Дамир САЛАХОВ
# Sentence:  директор ювелирного салона
# Sentence:  Аляска
# Sentence:
# Sentence: Иногда очень даже весело бывает пошутить над собой
# Sentence:
# Sentence: Екатерина Краснова
# Sentence: Какими словами вы бы встретили своё рождение
# Sentence:
# Sentence: Какая у вас в детстве была любимая игрушка
# Sentence:
# Sentence: Тогда многие об этом мечтали
# Sentence:
# Sentence: Врач тут же стал какой
# Sentence: то грустный
# Sentence:  и в училище меня в итоге не приняли
# Sentence:
# Sentence: Ещё кошки лечат мою хроническую язву
# Sentence:
# Sentence: Да
# Sentence:  кстати говорят
# Sentence:  что животные похожи на своих хозяев
# Sentence:
# Sentence: Были
# Sentence:  конечно
# Sentence:  как у всех
# Sentence:  свои проблемы
# Sentence:  но сейчас у меня уже четыре внучки
# Sentence:
# Sentence: В советском кино детективов тоже хватало
# Sentence:  но слишком уж они были положительные
# Sentence:
# Sentence: Ну
# Sentence:  например
# Sentence:  сейчас я не стал бы горланить на набережной песни
# Sentence:
# Sentence: В деревне мы часто дрались с переселенцами
# Sentence:  в школе
# Sentence:
# Sentence:  класс на класс или
# Sentence:  за мальчиков
# Sentence:  и
# Sentence:  за девочек
# Sentence:
# Sentence:
# Sentence: А что мне доставляет самое большое удовольствие
# Sentence:
# Sentence: Честно говоря
# Sentence:  я над этим не задумывался
# Sentence:
# Sentence: Живёт ли человек несколько жизней
# Sentence:  я не знаю
# Sentence:
# Sentence: Мы пошли туда с ребятами посидеть со стипендии
# Sentence:  а он как раз у нас
# Sentence:  в Самаре
# Sentence:  гастролировал
# Sentence:
# Sentence: Предложили ещё несколько раз
# Sentence:
# Sentence:  я опять никак не среагировал
# Sentence:
# Sentence: Якобы я
# Sentence:
# Sentence:  самый мафиозный чиновник
# Sentence:
# Sentence: Я это так запомнил потому
# Sentence:  что тогда произошёл забавный случай
# Sentence:
# Sentence: А недавно меня позабавил один сюжет по телевизору
# Sentence:
# Sentence: Мы ждём пятого ребёнка
# Sentence:
# Sentence: В общении Валентин Михайлович был очень приятным человеком
# Sentence:  поэтому
# Sentence:  когда у него возникли семейные проблемы
# Sentence:  мы коллективом старались помочь
# Sentence:  как могли
# Sentence:
# Sentence:
# Sentence:
# Sentence: В первую очередь он вышел на Середавина
# Sentence:  и моего мужа положили в больницу Калинина
# Sentence:
# Sentence: Больше всего меня покорило то
# Sentence:  что обычно мужчину интересует женщина как таковая
# Sentence:  а он совершенно искренне интересовался моими проблемами
# Sentence:  детьми
# Sentence:
# Sentence: С внучками Валентин Михайлович становится настоящим ребёнком
# Sentence:
# Sentence:  садится на пол
# Sentence:  играет в мяч
# Sentence:
# Sentence: Вместе мы очень любим отдыхать на природе
# Sentence:
# Sentence: Выходит ко мне
# Sentence:  удивлённый
# Sentence:  с целым тазиком мяса
# Sentence:
# Sentence: В общем
# Sentence:  о том
# Sentence:  что я вышла за Валентина Михайловича замуж
# Sentence:  я
# Sentence:  разумеется
# Sentence:  не жалею
# Sentence:
# Sentence: Быстро ко мне
# Sentence:
# Sentence:
# Sentence:
# Sentence:  не терпящим возражения тоном говорил он
# Sentence:
# Sentence: В седьмом часу в бутик подъехали специально приглашённые музыканты
# Sentence:
# Sentence: Около пятидесяти стильно одетых дам
# Sentence:
# Sentence:  оказавшиеся в этот момент на улице мужчины буквально шеи свернули
# Sentence:
# Sentence:  искренне радовались встрече у любимой Max Mara и активно строили догадки о причине выдворения всех за дверь
# Sentence:
# Sentence: Наибольшей популярностью у
# Sentence:  папарацци
# Sentence:
# Sentence:  разумеется
# Sentence:  пользовалась Наталья Титова
# Sentence:
# Sentence: Первые
# Sentence:
# Sentence:  непринужденно
# Sentence:  уверенно проходя по подиуму с немного дежурными улыбками
# Sentence:  вторые
# Sentence:
# Sentence:  слегка смущаясь
# Sentence:  но ничуть не хуже первых
# Sentence:
# Sentence: На подиуме я в первый раз
# Sentence:  но так понравилось
# Sentence:  что хочется ещё
# Sentence:
# Sentence:
# Sentence:
# Sentence:  рассказала
# Sentence:  Делу
# Sentence:  г
# Sentence: жа Швайкина
# Sentence:
# Sentence: Получив подробнейшую информацию о новомодных тенденциях
# Sentence:  гости отправились домой
# Sentence:  по ходу определяясь с покупками из новой коллекции и мечтая о летних дефиле на европейских и экзотических курортах
# Sentence:
# Sentence: Уже сейчас на имя министра транспорта Сергея Франка
# Sentence:  губернатора Самарской области Константина Титова составлена записка
# Sentence:  в которой излагается сложившаяся ситуация и содержится просьба принять меры по её исправлению
# Sentence:
# Sentence: В общем
# Sentence:  сплошные неудобства при перевозке этих порожних контейнеров
# Sentence:
# Sentence:
# Sentence: И
# Sentence:  конечно
# Sentence:  заплатить владельцу вагона за его эксплуатацию
# Sentence:
# Sentence: 21
# Sentence:  06
# Sentence:  2002
# Sentence: Однако возник он далеко не сразу
# Sentence:
# Sentence: Пока не начался непосредственно процесс банкротства
# Sentence:  Фонд имущества поспешил ещё раз выставить на торги оставшиеся у него акции
# Sentence:  Сызраньсельмаша
# Sentence:
# Sentence:
# Sentence:  22% акций
# Sentence:
# Sentence: Здесь
# Sentence:  наконец
# Sentence:  у пакета появились покупатели
# Sentence:
# Sentence: Но он снова не состоялся
# Sentence:
# Sentence:  два акционера
# Sentence:  Сызраньсельмаша
# Sentence:  обратились в Ленинский и Железнодорожный суды Самары с исками об отмене аукциона по той причине
# Sentence:  что ФИСО не поставил в известность акционеров об аукционе
# Sentence:
# Sentence: К середине 2000 года окончательно прояснились три группы
# Sentence:  которым в той или иной форме был интересен контроль над предприятием
# Sentence:
# Sentence: Предприятие группы
# Sentence:
# Sentence:
# Sentence:  РосЛада
# Sentence:
# Sentence:
# Sentence:  было одним из основных арендаторов
# Sentence:
# Sentence:  Сызраньсельмаша
# Sentence:
# Sentence:  и руководство
# Sentence:  РосЛады
# Sentence:  не раз заявляло о далеко идущих планах по развитию и расширению своего производства
# Sentence:
# Sentence: На площадях
# Sentence:  Сызраньсельмаша
# Sentence:  группой компаний
# Sentence:  СОК
# Sentence:  и АВТОВАЗом планировалось организовать производство кузовов и шасси для
# Sentence:  шестёрок
# Sentence:
# Sentence:
# Sentence: Соответственно целям
# Sentence:  оборудование для этого производства будет из
# Sentence:  Сызраньмельмаша
# Sentence:  передано
# Sentence:  Сельмашу
# Sentence:
# Sentence:
# Sentence: Мало того
# Sentence:  что завод
# Sentence:
# Sentence:  одно из ведущих местных предприятий
# Sentence:  так ещё и мэр Сызрани Василий Янин проработал на заводе 15 лет
# Sentence:
# Sentence: Обсуждать подобную открытость в весьма интимной для любого делового человека сфере кинулись буквально все
# Sentence:
# Sentence: Это находится в компетенции членов совета директоров
# Sentence:  а я не являюсь собственником предприятия
# Sentence:
# Sentence: Иван ШАВЕРНЕВ
# Sentence:
# Sentence: директор ОАО
# Sentence:  Самарапромсвязь
# Sentence:
# Sentence: Ещё 25
# Sentence:  5% акций находятся у государства
# Sentence:
# Sentence: Я по
# Sentence: прежнему остаюсь президентом телекомпании
# Sentence:  а Людмила Романовна
# Sentence:
# Sentence:  генеральным директором
# Sentence:
# Sentence: Я
# Sentence:  к примеру
# Sentence:  акционер
# Sentence:  прорабы
# Sentence:  монтажники
# Sentence:
# Sentence:  тоже акционеры
# Sentence:
# Sentence: Компания
# Sentence:  ЮКОС
# Sentence:  сделала этот шаг
# Sentence:  потому что у них сотни тысяч акционеров
# Sentence:
# Sentence: Феликс СНЫТКО
# Sentence:
# Sentence: Я могу поделиться лишь информацией
# Sentence:  которая касается лично меня
# Sentence:
# Sentence:  я являюсь владельцем 150 акций ОАО
# Sentence:  Волготанкер
# Sentence:
# Sentence:
# Sentence: Когда это случится
# Sentence:  о чём
# Sentence: то можно будет и поговорить
# Sentence:
# Sentence: Почему
# Sentence:
# Sentence: И не только руководителя
# Sentence:  но и простых сотрудников
# Sentence:
# Sentence: Мы же
# Sentence:
# Sentence:  мелкие акционеры
# Sentence:  работаем в узких сферах
# Sentence:
# Sentence: Эта
# Sentence:  туманность
# Sentence:
# Sentence:  в свою очередь
# Sentence:  влечёт за собой ситуации совершенно нелогичные и непредсказуемые
# Sentence:
# Sentence: Производилось пиво до 1917 года
# Sentence:  потом наступили не пивные времена
# Sentence:
# Sentence:  гражданская война
# Sentence:  военный коммунизм
# Sentence:  голод в Поволжье
# Sentence:
# Sentence: По словам Михаила Цыплакова
# Sentence:  юриста ОАО
# Sentence:  Жигулёвское пиво
# Sentence:
# Sentence:  документально доказывается
# Sentence:  что регистрация знака была инициирована не заводом
# Sentence:  а Всероссийским НИИ пивоваренной винодельческой и безалкогольной продукции
# Sentence:
# Sentence: ОАО
# Sentence:  Жигулёвское пиво
# Sentence:
# Sentence:  обладавшее
# Sentence:  согласно свидетельству от 1992 года
# Sentence:  правом собственности на товарный знак
# Sentence:  Жигулёвское
# Sentence:
# Sentence:  решило приступить к реализации своих исключительных прав и обратилось к предприятиям
# Sentence: правонарушителям
# Sentence:  то есть тем
# Sentence:  кто неправомерно использовал самарскую марку
# Sentence:  с предложением урегулировать вопрос её использования
# Sentence:
# Sentence: Патентные войны
# Sentence:
# Sentence: Но в России нет прецедентного права
# Sentence:  в результате чего
# Sentence:  Жигулёвское пиво
# Sentence:  оказалось на особом положении
# Sentence:
# Sentence: Разумеется
# Sentence:  Роспатент
# Sentence:  бюджет которого рассчитали с учётом завышенных расценок
# Sentence:  просто так не откажется от источника финансирования
# Sentence:
# Sentence: Кроме того
# Sentence:  как сказал Михаил Цыплаков
# Sentence:  ОАО
# Sentence:  Жигулёвское пиво
# Sentence:  готовит Роспатенту сюрпризы
# Sentence:
# Sentence: Что же всё
# Sentence: таки делать с общероссийскими брэндами
# Sentence:  сегодня так до конца и не решили
# Sentence:
# Sentence: Качество оставляет желать лучшего
# Sentence:
# Sentence: Например
# Sentence:  конфеты
# Sentence:  Мишка на севере
# Sentence:  выпускались в советское время только на ленинградской фабрике им
# Sentence:  Н
# Sentence:  К
# Sentence:  Крупской
# Sentence:  а
# Sentence:  Жигулёвское пиво
# Sentence:
# Sentence:
# Sentence:  всеми сразу
# Sentence:
# Sentence: Наталья Дядик
# Sentence: Глава Miramax Харви Вайнштейн будет награждён орденом Командора Британской империи
# Sentence:
# Sentence: До встречи с ним я считал себя актёром определённых возможностей
# Sentence:
# Sentence: Детство
# Sentence: Длинный коридор заканчивается окном
# ...
# ('люблю не', 0)
# ('груши', 0)
# ('но и родителей', 0)
# ('тут сидорову стало душно при', 0)
# ('мысли о', 0)
# ('воробьева', 0)
# ('заставить', 0)
# ('прыгать за каждым пирожком', 0)
# ('а потом выведет на прогулку', 0)
# ('ни влево', 0)
# ('корр', 0)
# ('полагаете', 0)
# ('сева иванович', 0)
# ('сейчас час', 0)
# ('домой отнести', 0)
# ('в каком ухе у', 0)
# ('звенит', 0)
# ('случай', 0)
# ('запомнился на', 0)
# ('очень важная часть', 0)
# ('часто вспоминаем о', 0)
# ('не видит дальше', 0)
# ('носа', 0)
# ('держать нос по ветру', 0)
# ('изменять', 0)
# ('принципам', 0)
# ('проживите по', 0)
# ('правилам', 0)
# ('и тогда у', 0)
# ('нос в табаке', 0)
# ('пишу', 0)
# ('в обычной речи', 0)
# ('иносказательно', 0)
# ('ещё и необычные загадки', 0)
# ('а не звери', 0)
# ('а луна', 0)
# ('а раньше вулкан спал', 0)
# ('спали и люди в округе', 0)
# ('не ведая', 0)
# ('в каждом из', 0)
# ('и в вулкане', 0)
# ('дремлют могучие силы земли', 0)
# ('силы творчества и созидания', 0)
# ('но тогда давай зададим', 0)
# ('ещё несколько вопросов', 0)
# ('а вот растения', 0)
# ('и двигаться', 0)
# ('и расти', 0)
# ('и чувствовать', 0)
# ('и почти умеют разговаривать', 0)
# ('подавать сигналы', 0)
# ('знания помогают ребятам овладеть искусством', 0)
# ('кастрюлищу', 0)
# ('а для', 0)
# ('нужен всеобщий язык', 0)
# ('плохо понимают друг друга', 0)
# ('язык у', 0)
# ('самая', 0)
# ('ская', 0)
# ('натолкнула', 0)
# ('на мысль', 0)
# ('получиться ещё много других слов', 0)
# ('запоминать', 0)
# ('необязательно', 0)
# ('язык', 0)
# ('никому не рассказывал', 0)
# ('вошли', 0)
# ('грамматика', 0)
# ('из 16 правил', 0)
# ('эсперанто начал', 0)
# ('суть', 0)
# ('трамвай', 0)
# ('усы', 0)
# ('и придумывается история', 0)
# ('бунин в раю', 0)
# ('природа', 0)
# ('самое лучшее и крепкое', 0)
# ('в мире', 0)
# ('бедные люди', 0)
# ('мучаются с петухами', 0)
# ('ни в зуб ногой', 0)
# ('ничего не знаете', 0)
# ('и вдобавок', 0)
# ('не по зубам', 0)
# ('не хватает умения', 0)
# ('не нужно понапрасну точить зубы', 0)
# ('испытывать злобу', 0)
# ('не уступая', 0)
# ('деле зубы съел', 0)
# ('имеет большой опыт', 0)
# ('и пусть', 0)
# ('видят', 0)
# ('ваши зубы', 0)
# ('согласно словарю эпитетов', 0)
# ('крупные и ровные', 0)
# ('острые и частые', 0)
# ('твёрдые', 0)
# ('жемчужные', 0)
# ('белые', 0)
# ('клыкастые', 0)
# ('мраморные', 0)
# ('крепкие', 0)
# ('самые смехастые', 0)
# ('гутц', 0)
# ('сагана', 0)
# ('а странная песня', 0)
# ('колдовское заклинание', 0)
# ('подойдя поближе', 0)
# ('алексей иванович узнал', 0)
# ('соседей', 0)
# ('тут почкин выложил', 0)
# ('про анну', 0)
# ('праздник ивана', 0)
# ('купалы загадочный и странный', 0)
# ('продолжал сан саныч', 0)
# ('жить рядом в человеческом сердце', 0)
# ('кладоискателю перво', 0)
# ('наперво историю изучать надо', 0)
# ('тогда заклинание надо произнести', 0)
# ('отойди ж', 0)
# ('нечистая сила', 0)
# ('положено', 0)
# ('и стеречь', 0)
# ('и всё на', 0)
# ('же месте', 0)
# ('внимание', 0)
# ('какую травку', 0)
# ('заинтересовались почкин и сан саныч', 0)
# ('там ведь двери железные', 0)
# ('замки пудовые', 0)
# ('черти завизжали', 0)
# ('не разбирая дороги', 0)
# ('за глупую песню ведьмы', 0)
# ('возмутился почкин', 0)
# ('звуковые', 0)
# ('маленькой белой кошкой', 0)
# ('услышав вздохи', 0)
# ('глянул вверх', 0)
# ('хочешь', 0)
# ('на флейте сыграю', 0)
# ('спросил повар', 0)
# ('и полез на дерево', 0)
# ('надо сделать укол', 0)
# ('на ум пришло', 0)
# ('плохо в', 0)
# ('разбираюсь', 0)
# ('собаку рыбкой угостить', 0)
# ('ведь не догадывались', 0)
# ('собака', 0)
# ('кошкой', 0)
# ('позже головню сменяют факелы', 0)
# ('изготовить сальную свечку', 0)
# ('изобретатели даже стараются', 0)
# ('чтобы лампы коптили', 0)
# ('а раскалённые в', 0)
# ('частички сажи', 0)
# ('из металла вольфрама', 0)
# ('заплатил эдисон за', 0)
# ('вклад в историю лампочки', 0)
# ('однако угольные стержни обгорают', 0)
# ('нужно постоянно сдвигать', 0)
# ('но сквозь тёмные стёкла', 0)
# ('разглядеть буквы', 0)
# ('не купишь ни в', 0)
# ('магазине', 0)
# ('гордился', 0)
# ('и до школы', 0)
# ('но в школе', 0)
# ('гордость приобрела особые размеры', 0)
# ('много лет назад', 0)
# ('ещё при царе', 0)
# ('прабабушка училась в гимназии', 0)
# ('круглой отличницей и получила за', 0)
# ('медаль из настоящего золота', 0)
# ('книг у прабабушки', 0)
# ('старинные церковные', 0)
# ('с металлическими застёжками', 0)
# ('подшивка журнала', 0)
# ('крокодил', 0)
# ('за 1938 год', 0)
# ('не мир', 0)
# ('но меч', 0)
# ('домашние животные', 0)
# ('скандал разразился в пятницу вечером', 0)
# ('на поезд опаздываю', 0)
# ('незнакомый мужской голос', 0)
# ('тётя лёля к', 0)
# ('туда не поехала', 0)
# ('и за', 0)
# ('прабабушка сильно её не уважала', 0)
# ('ханжа', 0)
# ('коробочкой', 0)
# ('домашнему называлось пространство за буфетом', 0)
# ('кирилл и мефодий', 0)
# ('сказала', 0)
# ('прабабушка', 0)
# ('византийскими дипломатами', 0)
# ('к арабам ходили', 0)
# ('к хазарам', 0)
# ('прабабушка умерла', 0)
# ('но тётя лёля', 0)
# ('жила последние годы', 0)
# ('сохранила сундук со старыми книгами', 0)
# ('понял', 0)
# ('в сердце каждого человека должно', 0)
# ('незыблемое', 0)
# ('всё осталось', 0)
# ('зарубежным гостем москвы', 0)
# ('взмахнуть', 0)
# ('возникает всякая польза', 0)
# ('хохот', 0)
# ('хочу стать', 0)
# ('ниткин', 0)
# ('объявляется открытым', 0)
# ('в круг', 0)
# ('тут уж почудилось со', 0)
# ('тогда получится две половинки яблока', 0)
# ('и великая тайна делимости вещества', 0)
# ('в природе существуют', 0)
# ('называемые кварки', 0)
# ('галактики же в', 0)
# ('очередь собраны в скопления галактик', 0)
# ('или всё', 0)
# ('таки существуют абсолютно неделимые частицы', 0)
# ('хотя бы', 0)
# ('же кварки', 0)
# ('а свет', 0)
# ('и если удастся', 0)
# ('нибудь обнаружить', 0)
# ('временные кванты', 0)
# ('разгадана ещё', 0)
# ('великая тайна мироздания', 0)
# ('тайна времени', 0)
# ('больше разгадываю', 0)
# ('больше передо', 0)
# ('новых тайн возникает', 0)
# ('такова легенда', 0)
# ('навещать', 0)
# ('в самом деле', 0)
# ('сколько всевозможных', 0)
# ('под властью доллара', 0)
# ('за океаном', 0)
# ('нового можно написать об', 0)
# ('европейских тарахтелках', 0)
# ('доходит до дела', 0)
# ('просят у родителей американский кар', 0)
# ('в горячем воздухе', 0)
# ('валится на', 0)
# ('сквозь окна машины', 0)
# ('хотя бы слабо представить', 0)
# ('самочувствие пионеров', 0)
# ('шедших день за днём по', 0)
# ('серой', 0)
# ('колючей', 0)
# ('бескрайней земле', 0)
# ('меж выветрившихся известняковых холмов', 0)
# ('истуканов', 0)
# ('в дрожащем мареве невады', 0)
# ('мимо однообразных призраков деревьев джошуа', 0)
# ('день за днём', 0)
# ('пока не открылась перед', 0)
# ('блаженная калифорния', 0)
# ('земля обетованная', 0)
# ('фрэнк синатра', 0)
# ('старый синеглазый', 0)
# ('помог', 0)
# ('встать', 0)
# ('объявление читается', 0)
# ('остановись', 0)
# ('блудливое перо', 0)
# ('хай', 0)
# ('сказал мемозов', 0)
# ('с приездом', 0)
# ('вообразите', 0)
# ('лорнет', 0)
# ('монокль', 0)
# ('пенсне на цепи', 0)
# ('хотите оплатить', 0)
# ('последнее слово мемозов', 0)
# ('бы пропел', 0)
# ('и москвич тогда тяжко подумал', 0)
# ('вот снова какая', 0)
# ('чушь', 0)
# ('досадная ерунда прикасается к', 0)
# ('сегодняшнему', 0)
# ('юному', 0)
# ('мемозов наконец замолчал', 0)
# ('началась', 0)
# ('и кончилась по', 0)
# ('воле', 0)
# ('субъект', 0)
# ('теперь всё опошлить', 0)
# ('изуродовать всё приключение', 0)
# ('и начинать', 0)
# ('ведь не собирался', 0)
# ('а вот сейчас приходится', 0)
# ('венеция', 0)
# ('вот моё первое утро в', 0)
# ('в нью', 0)
# ('йорке', 0)
# ('правила нет', 0)
# ('там смотри в оба', 0)
# ('кругорама', 0)
# ('находится автор', 0)
# ('газолиновые станции', 0)
# ('рекламы', 0)
# ('шины', 0)
# ('светофоры', 0)
# ('кофе', 0)
# ('шоп', 0)
# ('автостоянку', 0)
# ('мотоциклы', 0)
# ('ящики с газетами', 0)
# ('пальмы', 0)
# ('итальянский ресторанчик', 0)
# ('небоскрёб', 0)
# ('морскую пехоту', 0)
# ('в следующем мгновении появилась и', 0)
# ('хозяйка ноги', 0)
# ('а потом и друг ноги', 0)
# ('беленький пудель', 0)
# ('вечерами сверкающие бесчисленными фарами', 0)
# ('в сердце суперцивилизации', 0)
# ('в административном отношении мегалополис лос', 0)
# ('друзья говорили', 0)
# ('на уилшире недавно откопали динозавра', 0)
# ('вдруг вижу', 0)
# ('джека', 0)
# ('выскочил паренёк с тремя подносами', 0)
# ('дымящаяся еда', 0)
# ('щека красная', 0)
# ('другая зелёная', 0)
# ('повсюду', 0)
# ('дымы', 0)
# ('багровые', 0)
# ('оранжевые', 0)
# ('зелёные жёлтые', 0)
# ('явные яды', 0)
# ('а любимое', 0)
# ('светило', 0)
# ('закатываясь в', 0)
# ('напоминало главный яд', 0)
# ('резервуар', 0)
# ('страшных ядов', 0)
# ('мелькали босые пятки', 0)
# ('money', 0)
# ('жутким голосом', 0)
# ('напомнившим', 0)
# ('режиссёра', 0)
# ('мосфильма', 0)
# ('завопил пророк', 0)
# ('money is shit', 0)
# ('green shit', 0)
# ('вдали', 0)
# ('в нескольких кварталах от', 0)
# ('впрямую будто на эстраде запел', 0)
# ('садитесь', 0)
# ('сказал голос в трубке', 0)
# ('недоумевал москвич', 0)
# ('санта', 0)
# ('моника', 0)
# ('фривэй кончался тоннелем', 0)
# ('и там машины', 0)
# ('еле ползли', 0)
# ('образовался', 0)
# ('джэм', 0)
# ('автомобильная пробка', 0)
# ('с блохой на поводке', 0)
# ('а скорость между', 0)
# ('всё увеличивалась', 0)
# ('открылись двери', 0)
# ('шум многих голосов', 0)
# ('смех', 0)
# ('нравится', 0)
# ('ответил москвич', 0)
# ('принимая бокал', 0)
# ('во взглядах', 0)
# ('устремлённых на', 0)
# ('дальнейшие вопросы неуместны', 0)
# ('семнадцать', 0)
# ('семь', 0)
# ('восемнадцать', 0)
# ('девятнадцать', 0)
# ('двадцать', 0)
# ('аут', 0)
# ('гулко и издевательски', 0)
# ('словно ворон', 0)
# ('отсчитывал ужаснейший', 0)
# ('сразу догадался москвич', 0)
# ('предосаднейший продукт воображения', 0)
# ('мемозов', 0)
# ('отомстить и разоблачить прохвоста', 0)
# ('подумал москвич и вдруг увидел', 0)
# ('не в подземелье', 0)
# ('а на открытой просторной веранде', 0)
# ('не прошло и пяти минут', 0)
# ('покачивая на прощанье серебристыми крыльями', 0)
# ('университет калифорнии огромен', 0)
# ('да неужели', 0)
# ('самая знаменитая', 0)
# ('лежащая фигура', 0)
# ('генри мура', 0)
# ('медведи', 0)
# ('из ucla', 0)
# ('замечаю', 0)
# ('парни и девочки несут книги', 0)
# ('лежат на траве с книгами', 0)
# ('сидят в студенческих кафе', 0)
# ('можно сделать неожиданные открытия', 0)
# ('энтони берджес', 0)
# ('сблизив', 0)
# ('show', 0)
# ('выбежал из', 0)
# ('маленького', 0)
# ('клермонт', 0)
# ('отеля', 0)
# ('на тивертон', 0)
# ('возглавлявший комиссию по расследованию', 0)
# ('индустрия развлечений в диснейленде', 0)
# ('тоталитаризм', 0)
# ('или иначе', 0)
# ('диалектических', 0)
# ('кинематографических образов', 0)
# ('средний американец', 0)
# ('ковбой', 0)
# ('шериф', 0)
# ('в небрежном костюме', 0)
# ('скюбент', 0)
# ('сицилист', 0)
# ('аблакат', 0)
# ('делаем вместе два круга', 0)
# ('а потом джей', 0)
# ('джей', 0)
# ('джей говорит', 0)
# ('гордым и высоким', 0)
# ('и вспоминаю', 0)
# ('первую лекцию', 0)
# ('назвать лекцией', 0)
# ('несокрушимый и сильно вооружённый', 0)
# ('стоял с непонятной улыбкой', 0)
# ('в небе образовалось окно', 0)
# ('о чём ещё', 0)
# ('хвала и бумаге', 0)
# ('закончив', 0)
# ('лекцию', 0)
# ('не нашёл ничего лучшего', 0)
# ('спросить', 0)
# ('вижу плохо скрытый восторг', 0)
# ('из поспоривших подруг', 0)
# ('разочарование и неудовольствие другой', 0)
# ('не понимает ни слова из', 0)
# ('экзерсисов', 0)
# ('заинтересовало в современной советской прозе', 0)
# ('знали ли', 0)
# ('достаточно язык', 0)
# ('тихо и мирно', 0)
# ('меняли', 0)
# ('катушки в магнитофоне', 0)
# ('в голову счастливая идея', 0)
# ('пустить среди', 0)
# ('друзей анкету', 0)
# ('снова пошёл на хитрость', 0)
# ('лекций', 0)
# ('пришлось показать книгу', 0)
# ('читал и тираж', 0)
# ('сто тысяч экземпляров', 0)
# ('катаев прав', 0)
# ('ведь пустоты не существует', 0)
# ('ведь мир же материален', 0)
# ('здесь упоминается также ю', 0)
# ('эф', 0)
# ('оу', 0)
# ('неопознанный летающий объект', 0)
# ('не согласен', 0)
# ('не согласны', 0)
# ('человечество', 0)
# ('<br> </br>', 0)
# ('пишешь <br> </br>', 0)
# ('любишь', 0)
# ('ненавидишь <br> </br>', 0)
# ('москвич очнулся', 0)
# ('увидел над', 0)
# ('беломраморное изваяние', 0)
# ('величественного', 0)
# ('главная пещера имела ответвления', 0)
# ('ниши', 0)
# ('заливы', 0)
# ('проливы', 0)
# ('и оттуда выплывали навстречу москвичу', 0)
# ('витрины с бриллиантами', 0)
# ('многотысячные меха', 0)
# ('вдруг маленькая япония эпохи мэйдзи', 0)
# ('маленькая елизаветинская англия и наконец', 0)
# ('корабль клеопатры собственной персоной', 0)
# ('бэндом на корме', 0)
# ('лучше уж миллион выиграть', 0)
# ('голову потерять', 0)
# ('важно другое', 0)
# ('москвичу понравился университетский математик', 0)
# ('пойдёте по', 0)
# ('ряду', 0)
# ('по соседнему', 0)
# ('вскоре место действия', 0)
# ('оцеплено охраной', 0)
# ('паласа', 0)
# ('и муниципальной полицией лас', 0)
# ('вегасе', 0)
# ('необходимо развенчать ещё при жизни', 0)
# ('поколения', 0)
# ('сейчас и делаем', 0)
# ('загоготал', 0)
# ('подтолкнул к москвичу тележку с', 0)
# ('плотоядно потирая руки', 0)
# ('стабильности', 0)
# ('задохнулся от возмущения москвич', 0)
# ('оскорбляете подобными предложениями', 0)
# ('раздвинулись шторы', 0)
# ('сизар', 0)
# ('и москвич', 0)
# ('пока бежал', 0)
# ('видеть', 0)
# ('а потом и мешки с', 0)
# ('называемым золотом', 0)
# ('а потом неожиданно', 0)
# ('гадина жива', 0)
# ('началась свистопляска', 0)
# ('давка', 0)
# ('безумие', 0)
# ('нон', 0)
# ('стоп', 0)
# ('take care', 0)
# ('москвич', 0)
# ('будто из дальних времён', 0)
# ('и потомок пилигримов исчез окончательно', 0)
# ('движение и стиль', 0)
# ('в лондоне', 0)
# ('особый', 0)
# ('предреволюционный аромат', 0)
# ('на портобелло', 0)
# ('роад двухверстные ряды <br> </br>', 0)
# ('базар шарманщиков', 0)
# ('обманщиков <br> </br>', 0)
# ('адвокатов и акробатов <br> </br>', 0)
# ('турецкой кожи', 0)
# ('индийской лажи <br> </br>', 0)
# ('испанской бахромы', 0)
# ('и лётчиков хромых <br> </br>', 0)
# ('и треугольных шляп <br> </br>', 0)
# ('у мистера тяп', 0)
# ('ляп <br> </br>', 0)
# ('томов лохматой прозы <br> </br>', 0)
# ('у мистера гриппозо <br> </br>', 0)
# ('эму и какаду <br> </br>', 0)
# ('свободны', 0)
# ('даже и не предполагал', 0)
# ('говорите сами', 0)
# ('выслушают', 0)
# ('встречные спрашивали полицейских', 0)
# ('пройти к', 0)
# ('залитый огнём реклам сансет', 0)
# ('стрип', 0)
# ('здесь родилось', 0)
# ('возле ресторана', 0)
# ('жгли костёр', 0)
# ('кружились вороны', 0)
# ('пасифик', 0)
# ('коуст', 0)
# ('хайвэй буквально', 0)
# ('усыпан хиппи', 0)
# ('хичхайкерами', 0)
# ('странах запада оформилось', 0)
# ('развилось', 0)
# ('разрослось явление', 0)
# ('стиль хиппи', 0)
# ('лондон тогда поразил', 0)
# ('обилием солнца и молодёжи', 0)
# ('ещё долго бунтовали', 0)
# ('забыв про', 0)
# ('власть цветов', 0)
# ('превращая кампусы в осаждённые города', 0)
# ('требуя', 0)
# ('профессор показал подбородком и тростью', 0)
# ('слегка', 0)
# ('тоже прислушался', 0)
# ('чёрный красавец играл', 0)
# ('очень простое', 0)
# ('лирическое', 0)
# ('из средневековых английских баллад', 0)
# ('хиппи шли дорогой контрабандистов', 0)
# ('но в обратном направлении', 0)
# ('к маковым полям', 0)
# ('индию', 0)
# ('бангладеш', 0)
# ('непал', 0)
# ('тоже казалось', 0)
# ('односложные словечки', 0)
# ('грасс', 0)
# ('доп', 0)
# ('роч', 0)
# ('заехал на паркинг', 0)
# ('лот', 0)
# ('выпрыгнула из машины', 0)
# ('смеясь', 0)
# ('затем бычок превращается в', 0)
# ('называется чинарик', 0)
# ('а в калифорнии', 0)
# ('нежто', 0)
# ('полопались', 0)
# ('очередные', 0)
# ('пузыри земли', 0)
# ('называется', 0)
# ('довольно забавно', 0)
# ('впрямую переводится', 0)
# ('но если представить', 0)
# ('ресторан подобного рода в москве', 0)
# ('следует перевести иначе', 0)
# ('нибудь вроде', 0)
# ('министерство пищевой промышленности рсфср', 0)
# ('быстро передав заказ на кухню', 0)
# ('длинноволосый паренёк бросается к пианино', 0)
# ('играет и поёт', 0)
# ('леди мадонна', 0)
# ('уменьшении числа вегетативных балбесов частично', 0)
# ('виноваты', 0)
# ('и хиппи', 0)
# ('толпа', 0)
# ('же густая и яркая', 0)
# ('всё время не оставляет ощущение', 0)
# ('<em>обычная </em> западная толпа', 0)
# ('барабан', 0)
# ('играет на', 0)
# ('с помощью ножной педали', 0)
# ('щедры', 0)
# ('горячая декада англо', 0)
# ('в одессе говорят', 0)
# ('ещё не вечер', 0)
# ('вообще пока', 0)
# ('штука вертится', 0)
# ('москвич пожалел', 0)
# ('нет у', 0)
# ('похлопал', 0)
# ('по соответствующему месту и обнаружил', 0)
# ('пояс на', 0)
# ('на соответствующем месте', 0)
# ('прилетел к', 0)
# ('ждал очередного', 0)
# ('дождался бы', 0)
# ('приключение', 0)
# ('довести до крайностей', 0)
# ('полтора доллара для взрослых', 0)
# ('бы увядая', 0)
# ('простите', 0)
# ('друг', 0)
# ('не хотела бы', 0)
# ('огорчать', 0)
# ('но если у', 0)
# ('нет билета', 0)
# ('вынуждена', 0)
# ('снова', 0)
# ('самый босс', 0)
# ('каньона', 0)
# ('славные рожи джонов уэйнов', 0)
# ('гарри куперов', 0)
# ('грегори пеков', 0)
# ('кларков гейблов весело подмигивали', 0)
# ('искал ли', 0)
# ('нибудь из', 0)
# ('упала на вествуд', 0)
# ('бульваре около полуночи', 0)
# ('собравшейся в', 0)
# ('шалаше старого макдональда', 0)
# ('спрашиваете', 0)
# ('ли смысл', 0)
# ('раз уж', 0)
# ('начали', 0)
# ('оставайтесь', 0)
